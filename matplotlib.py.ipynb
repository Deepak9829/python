# %%
from matplotlib import pyplot as plt
import numpy as np
plt.plot([1,2,3,4],[5,3,6,4],'r1',label='linel')
plt.plot([1,2,3,4],[5,3,6,8],linewidth=5,label='line2')
plt.plot([2,3,4,5],[4,5,6,7],'ro-',label='line3')
plt.plot([1,2,3,4],[5,6,4,3],color='red',
linestyle='-',marker='o',markersize='5',markerfacecolor='g')
plt.axis([0,10,0,20])
plt.show()
t=np.arange(0,5,.2)
plt.plot(t,t,'r--',t,t**2,'bo',t,t**4,'c^')

# %%
from matplotlib import pyplot as plt
x=[5,2,7]
y=[2,16,4]
plt.plot(x,y)
plt.title('Info')
plt.ylabel('y axis')
plt.xlabel('x axis')
plt.show()

# %%
from matplotlib import style
x=[5,8,10]
y=[12,16,6]
x2=[6,9,11]
y2=[6,15,7]
plt.plot(x,y,'g',label='line one',linewidth=5)
plt.plot(x2,y2,'c',label='line two',linewidth=5)
plt.title('Epic Info')
plt.ylabel('y axis')
plt.xlabel('x axis')
plt.legend()
plt.grid(True,color='k')
plt.show()

# %%
from matplotlib import pyplot as plt
plt.bar([0.25,1.25,2.25,3.25,4.25],[50,40,70,80,20],
label="BMW",color='r',width=.1)
plt.bar([.75,1.75,2.75,3.75,4.75],[80,20,20,50,60],
label="Audi",color='b',width=.5)
plt.legend()
plt.ylabel('distance(kms)')
plt.title('Information')
plt.show()

# %%
import matplotlib.pyplot as plt
population_age=[22,55,62,45,21,22,34,56,32,
                58,65,58,31,65,54,69,52,35,45,25,58,36,56]
bins=np.arange(1,200)
plt.hist(population_age,bins,histtype='bar',rwidth=0.8)
plt.xlabel('age groups')
plt.ylabel('Number of people')
plt.title('Histogram')
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,1.5,2,2.5,3,3.5,3.6]
y=[7.5,8,8.5,9,9.5,10,10.5]
x1=[8,8.5,9,9.5,10,10.5,11]
y1=[3,3.5,4,4.5,5,5.5,5.6]

plt.scatter(x,y,label='high income low saving',color='r')
plt.scatter(x1,y1,label='low income high saving',color='b')
plt.xlabel('saving*100')
plt.ylabel('income*1000')
plt.title('Scatter plot')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
days=[1,2,3,4,5]
eating=[1,2,5,6,7]
working=[1,2,3,4,5]
sleeping=[75,8,65,11,7]
playing=[82,55,57,81,53]

plt.plot([],[],color='m',label='sleeping',linewidth=5)
plt.plot([],[],color='c',label='eating',linewidth=5)
plt.plot([],[],color='r',label='working',linewidth=5)
plt.plot([],[],color='k',label='playing',linewidth=5)
plt.stackplot(days,sleeping,eating,working,playing,
             colors=['m','c','r','k'])
plt.xlabel('x')
plt.ylabel('y')
plt.title('stack plot')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
days=[1,2,3,4,5]
working=[1,2,3,4,5]
sleeping=[7,8,6,11,7]
playing=[8,5,7,8,13]
slices=[7,8,2,6]
activities=['sleeping','eating','working','playing']
cols=['c','m','r','b']
plt.pie(slices,
       labels=activities,
       colors=cols,
       startangle=90,
       shadow=True,)
plt.title('pie plot')
plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt

def f(t):
    return np.exp(-t)*np.cos(2*np.pi*t)
t1=np.arange(0.0,5.0,0.02)
t2=np.arange(0.0,5.0,0.02)
plt.subplot(211)
plt.plot(t1,f(t1),'bo',t2,f(t2))
plt.subplot(212)
plt.plot(t2,np.cos(2*np.pi*t2))
plt.show()

# %%
#compute the x and y cordinates for points on an sine curve.
x= np.arange(0,3*np.pi,0.1)
y=np.sin(x)
# plot the points using matplotlib
plt.plot(x,y)
plt.show() #you must call plt.show() to make garphics appear.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-bd552e55443e> in <module>()
#       1 #compute the x and y cordinates for points on an sine curve.
# ----> 2 x= np.arange(0,3*np.pi,0.1)
#       3 y=np.sin(x)
#       4 # plot the points using matplotlib
#       5 plt.plot(x,y)
#
# NameError: name 'np' is not defined

# %%
#compute the x and y cordinates for points on an cos curve.
import matplotlib.pyplot as plt

import numpy as np
x= np.arange(0,3*np.pi,0.1)
y=np.cos(x)
# plot the points using matplotlib
plt.plot(x,y)
plt.show() #you must call plt.show() to make garphics appear.
