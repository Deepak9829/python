# %%
import pandas as pd
import numpy as np
s1 = pd.Series(np.random.randn(4))
print(s1)

# %%
print(s1.index)

# %%
s2= pd.Series(np.random.randn(5), index=['a','b','c','d','e'])
print(s2)

# %%
print(s2.index)

# %%
# create a series by dictionary
data ={'deepak':20,'arun':19}
print(s2)
s2=pd.Series(data)

# %%
# reodering the elements
s4= pd.Series(data, index=['arun','deepak'])
print(s4)

# %%
s5= pd.Series(2,index=range(10),name='ones')
print(s5)

# %%
dir(s4)

# %%
print('median',s4.median())

# %%
s1[s1>0]

# %%
s4[s4>s4.median()]

# %%
np.exp(s1)

# %%
s5=pd.Series(range(6))
s5[1:]+s5[:-1]

# %% [markdown]
# Pandas DataFrame:
# Pandas DataFrame is two-dimensional, size-mutable, heterogeneous tabular data structure with labeled rows and columns ( axes ). Can be thought of a dictionary-like container to store python Series objects.

# %%
data_frame =pd.DataFrame({"Name":pd.Series(["deepak =","rahul =","arun ="]),
                         "Age":pd.Series([20,16,5])})
print(data_frame)

# %%
data_frame["height"]=pd.Series([5.6,5.7,3])

# %%
data_frame

# %%
#read csv file
A=pd.read_csv("F://deepak//Salaries.csv")

# %%
A

# %%
A.head(10)

# %%
A.head()

# %%
A.tail(10)

# %%
type(A)

# %%
A['salary'].dtype

# %%
A['rank'].dtype

# %%
A.dtypes

# %%
A.columns

# %%
A.axes

# %%
A.ndim

# %%
A.size

# %%
A.shape

# %%
A.describe()

# %%
A.mean()

# %%
A.std()

# %%
B=A.head(50)
B.mean()

# %% [markdown]
# data slicing and grouping

# %%
A['sex'].head()

# %%
A['phd'].head()

# %%
#Calculate the basic statistics for the salary column (used describe() method)
# <your code goes here>
A['salary'].describe()

# %%
#Calculate how many values in the salary column (use count() method)
# <your code goes here>
A['salary'].count()

# %%
#Calculate the average salary
A['salary'].mean()

# %%
#Group data using rank
df_rank = A.groupby('rank')
df_rank

# %%
df_rank.mean()

# %%
#Group data using rank
df_rank = A.groupby('sex')
df_rank

# %%
df_rank.mean()

# %%
#Calculate the mean salary for men and women. The following produce Pandas Series (single brackets around salary)
A.groupby('sex')['salary'].mean()

# %%
A.groupby('rank')['service'].mean()

# %%
# If we use double brackets Pandas will produce a DataFrame
A.groupby('sex')[['salary']].mean()

# %%
A.groupby(['rank','sex'],sort=True)[['salary']].mean()

# %%
# Group data by the discipline and find the average salary for each group
A.groupby('discipline')['salary'].mean()

# %% [markdown]
# # Filtering

# %%
df_head= A[A['salary']>12000]
df_head.mean()

# %%
df_head.axes

# %%
#Select data for female professors
df_w = A[ A['sex'] == 'Female']
df_w.head()

# %%
# Using filtering, find the mean value of the salary for the discipline A
A[ A['discipline'] =='A'].mean().round(2)#round of 2 values

# %%
# Challange:
# Extract (filter) only observations with high salary ( > 100K) 
# and find how many female and male professors in each group
df_high= A.groupby(['sex','rank']).df
df=A[A['salary']>10000]
df_high

# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
import webbrowser
website="https://en.wikipedia.org/wiki/2016_Summer_Olympics"
webbrowser.open(website)
# Out:
# True

# %%
my_frame=pd.read_clipboard()
my_frame
# Out:
#                 Rank                          NOC  Gold  Silver  Bronze  Total
# 0                  1          United States (USA)    46      37      38    121
# 1                  2          Great Britain (GBR)    27      23      17     67
# 2                  3                  China (CHN)    26      18      26     70
# 3                  4                 Russia (RUS)    19      17      20     56
# 4                  5                Germany (GER)    17      10      15     42
# 5                  6                  Japan (JPN)    12       8      21     41
# 6                  7                 France (FRA)    10      18      14     42
# 7                  8            South Korea (KOR)     9       3       9     21
# 8                  9                  Italy (ITA)     8      12       8     28
# 9                 10              Australia (AUS)     8      11      10     29
# 10                11            Netherlands (NED)     8       7       4     19
# ...

# %%
DataFrame(my_frame,columns=['rank','NOC','Total','Stadium'])
# Out:
#     rank                          NOC  Total  Stadium
# 0    NaN          United States (USA)    121      NaN
# 1    NaN          Great Britain (GBR)     67      NaN
# 2    NaN                  China (CHN)     70      NaN
# 3    NaN                 Russia (RUS)     56      NaN
# 4    NaN                Germany (GER)     42      NaN
# 5    NaN                  Japan (JPN)     41      NaN
# 6    NaN                 France (FRA)     42      NaN
# 7    NaN            South Korea (KOR)     21      NaN
# 8    NaN                  Italy (ITA)     28      NaN
# 9    NaN              Australia (AUS)     29      NaN
# 10   NaN            Netherlands (NED)     19      NaN
# 11   NaN                Hungary (HUN)     15      NaN
# 12   NaN                Brazil (BRA)*     19      NaN
# 13   NaN                  Spain (ESP)     17      NaN
# 14   NaN                  Kenya (KEN)     13      NaN
# 15   NaN                Jamaica (JAM)     11      NaN
# ...

# %%
my_frame
# Out:
#                 Rank                          NOC  Gold  Silver  Bronze  Total
# 0                  1          United States (USA)    46      37      38    121
# 1                  2          Great Britain (GBR)    27      23      17     67
# 2                  3                  China (CHN)    26      18      26     70
# 3                  4                 Russia (RUS)    19      17      20     56
# 4                  5                Germany (GER)    17      10      15     42
# 5                  6                  Japan (JPN)    12       8      21     41
# 6                  7                 France (FRA)    10      18      14     42
# 7                  8            South Korea (KOR)     9       3       9     21
# 8                  9                  Italy (ITA)     8      12       8     28
# 9                 10              Australia (AUS)     8      11      10     29
# 10                11            Netherlands (NED)     8       7       4     19
# ...

# %%
A=print(my_frame.iloc())
