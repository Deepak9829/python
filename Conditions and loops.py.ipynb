# %%
#Single Line Suites:-
var=11
if(var == 10): 
    print ("Value of expression is 100")
print ("Good bye!")
# Out:
# Good bye!

# %%
#Note:-Python programming language assumes any non-zero and non-null values as TRUE, and if it is either zero or null, then it is assumed as FALSE value.
var1 = 100
if var1==101:
    
    print("1 - Got a true expression value")
    
    print ("var1")
else:
    
    
    print("1 - Got a false expression value")
    print ("var1")

var2 = 0
if var2:
    print ("2 - Got a true expression value")
    
    print ("var2")
    
else:
        
        print ("2 - Got a false expression value")
        
        print ("var2")
        

        print ("Good bye!")
# Out:
# 1 - Got a true expression value
# var1
# 2 - Got a false expression value
# var2
# Good bye!

# %%
#Elif Statements:-
var = 100
if var == 200:
    print ("1 - Got a true expression value")
    print ("var")
    
elif var == 150:
    print ("2 - Got a true expression value")
    print ("var")
elif var == 100:
    
    print ("Prateek Saxena")
    print ("var")
else:
    print ("4 - Got a false expression value")
    print ("var")

print ("Good bye!")
# Out:
# Prateek Saxena
# var
# Good bye!

# %%
#1.Write a python program to check the number is even or odd
i=int(input("enter a number"))
if (i%2==0):
    print("the number is even")
else:
    print("the number is odd")
# Out:
# enter a number5
# the number is odd

# %%
#2.Write a python Program to check the whether number is Positive or Negative or Zero.
i=int(input("enter a number:"))
num=i
if(num>0):
    print("the number is positive",num)
elif num==0:
    print("the number is zero",num)
else:
    print("the number is negative",num)
# Out:
# enter a number:18
# the number is positive 18

# %%
#3.Write a python program to check a leap year or not.
year=int(input("enter a year:"))
if(year%4==0):
    if(year%100==0):
        if(year%400==0):
            print("the year is a leap year",year)
        else:
                
                print("the year is a not a leap year",year)
    
    
    else:
        
        print("the year is leap year",year)
        
        
        
else:
            
            print("the year is not a leap",year)
# Out:
# enter a year:2020
# the year is leap year 2020

# %%
#4.Write a python program to find the Largest Among Three numbers
num1=int(input("enter first number: "))
num2=int(input("enter second number:"))
num3=int(input("enter third number:"))
if (num1>=num2) and (num1>=num3):
    largest=num1
elif (num2>=num1) and (num2>=num3):
    largest=num2
else:
    largest=num3
print("the largest number ",num1,num2,num3,"is",largest)
# Out:
# enter first number: 45
# enter second number:7
# enter third number:18
# the largest number  45 7 18 is 45

# %%
#5.Find the Factorial Number.
num=int(input("enter a number"))
factorial=1
if(num<0):
    print("The factorial does not exist for the negative numbers")
elif(num==1): 
    print("The Factiral 0 is 1")
else:
    for i in range(1,num+1):
        factorial =factorial*i
print("the factorial number",num,"is",factorial)
# Out:
# enter a number5
# the factorial number 5 is 120

# %%
#6.Write a Python program to find those numbers which are divisible by 7 and multiple of 5.
x=int(input("enter the lower range"))
y=int(input("enter the upper range"))
for i in range(x,y+1):
    if(i%7==0) and (i%5==0):
        print(i)

# %%
#7.1:-Write a Python program that prints all the numbers from 0 to 6 except 3 and 6.
#Note:-Use Continue Statement
for i in range(0,6):
    if(i==3 or i==6):
        
        continue
    print(i,end="")
print("\n")

# %%
#7.2:-Write a Python program that prints all the numbers from 0 to 6 except 3 and 6.
for i in range(0,6):
    if(i!=3 and i!=6):
        print(i)

# %%
#8.Write a Python program which accepts a sequence of comma separated 4 digit binary numbers as its input and print the numbers that are divisible by 5 in a comma separated sequence.
x=int(input("enter a number:"))
for i in range(1000,9999):
    if(i%5==0):
        print(i)
# Out:
# enter a number:1500
# 1000
# 1005
# 1010
# 1015
# 1020
# 1025
# 1030
# 1035
# 1040
# 1045
# 1050
# 1055
# 1060
# 1065
# 1070
# 1075
# 1080
# 1085
# 1090
# 1095
# 1100
# 1105
# 1110
# 1115
# 1120
# 1125
# 1130
# 1135
# 1140
# 1145
# 1150
# 1155
# 1160
# 1165
# 1170
# 1175
# 1180
# 1185
# 1190
# 1195
# 1200
# 1205
# 1210
# 1215
# 1220
# 1225
# 1230
# 1235
# 1240
# 1245
# 1250
# 1255
# 1260
# 1265
# 1270
# 1275
# 1280
# 1285
# 1290
# 1295
# 1300
# 1305
# 1310
# 1315
# 1320
# 1325
# 1330
# 1335
# 1340
# 1345
# 1350
# 1355
# 1360
# 1365
# 1370
# 1375
# 1380
# 1385
# 1390
# 1395
# 1400
# 1405
# 1410
# 1415
# 1420
# 1425
# 1430
# 1435
# 1440
# 1445
# 1450
# 1455
# 1460
# 1465
# 1470
# 1475
# 1480
# 1485
# 1490
# 1495
# 1500
# 1505
# 1510
# 1515
# 1520
# 1525
# 1530
# 1535
# 1540
# 1545
# 1550
# 1555
# 1560
# 1565
# 1570
# 1575
# 1580
# 1585
# 1590
# 1595
# 1600
# 1605
# 1610
# 1615
# 1620
# 1625
# 1630
# 1635
# 1640
# 1645
# 1650
# 1655
# 1660
# 1665
# 1670
# 1675
# 1680
# 1685
# 1690
# ...

# %%
#9.Write a python program to check whether number is vowel or consonant.
x=input("enter any alphabet")
if(x=='a' or x=='e' or x=='i' or x=='o' or x=='u' and (x==
  'A' or x=='E' or x=='I' or x=='O' or 'U')):
    print("the alphabet is vowel",x)
else:
    print("the alphabet is consonant",x)
# Out:
# enter any alphabetp
# the alphabet is consonant p

# %%
#10.Write a python program to Multiplication table from 1 to 2.
num=int(input("enter a number"))
for i in range(1,num+1):
    for j in range(1,11):
        print(i,"x",j,"=",i*j)
# Out:
# enter a number2
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# 1 x 6 = 6
# 1 x 7 = 7
# 1 x 8 = 8
# 1 x 9 = 9
# 1 x 10 = 10
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20

# %%
#Alphabet Patterns:-
#11.Write a paython program to print alphabet patttern 'A'.(First Shape)

for row in range(0,7):
    for col in range(0,5):
        if((col==0 or col==4) or (row==0 or row==3) and (col>0 and col<4)):
            print("*",end="")
        
        else:
            print(end=" ")
    print()
# Out:
# *****
# *   *
# *   *
# *****
# *   *
# *   *
# *   *

# %%
#11.1:-Write a python program to print alphabet pattern'A'(Second Shape)

for row in range(0,7):
    for col in range(0,5):
        if((col==0 or col==4) and (row!=0)) or ((row==0 or row==3) and (col>0 and col<4)):
            print("*",end="")
        else:
            print(end=" ")
    print()
# Out:
#  ***
# *   *
# *   *
# *****
# *   *
# *   *
# *   *

# %%
#12.:-Write a python program to print alphabet pattern 'B'.(First Shape)

for row in range(0,7):
    for col in range(0,5):
        if (col==0 or col==4) or ((row==0 or row==3 or row==6) and (col>0 and col<4)):
            print("*",end="")
        else:
            print(end=" ")
       
    print()
# Out:
# *****
# *   *
# *   *
# *****
# *   *
# *   *
# *****

# %%
#12.2:-Write a python program to print alphabet pattern 'B'.(Second Shape)

for row in range(0,7):
    for col in range(0,5):
        
        if(col==0) or (col==4 and (row!=0 and row!=3 and row!=6)) or((row==0 or row==3 or row==6)) and (col>0 and col<4):
                       print("*",end="")
        else:
                       print(end=" ")
                       
    print()
# Out:
# ****
# *   *
# *   *
# ****
# *   *
# *   *
# ****

# %%
#13.Write a python program to print alphabet pattern C.(First Shape)

for row in range(0,7):
    for col in range(0,5):
        if(col==0) or (row==0 or row==6) and (col>0):
                       print("*",end="")
        else:
                       print(end=" ")
                       
    print()
# Out:
# *****
# *
# *
# *
# *
# *
# *****

# %%
#13.1 Write a python program to print alphabet pattern C.(Second Shape)

for row in range(0,7):
    for col in range(0,5):
        if(col==0 and (row!=0 and row!=6)) or (row==0 or row==6) and (col>0):
                     print("*",end="")
        else:
                     print(end=" ")
    print()
# Out:
#  ****
# *
# *
# *
# *
# *
#  ****

# %%
#14.Write a python program to print alphabet pattern D.(First shape)

for row in range(0,7):
    for col in range(0,7):
        if((col==4 or col==1) or (row==0 or row==6) and (col<4)):
            print("*",end="")
        else:
            print(end=" ")
    print()
# Out:
# *****
#  *  *
#  *  *
#  *  *
#  *  *
#  *  *
# *****

# %%
#14.1 Write a python program to print alphabet pattern D.(Second Shape)

for row in range (0,7):
    for col in range(0,6):
        if((col==4 or col==1) and (row!=0 and row!=6) or (row==0 or row==6) and (col<4)):
            print("*",end="")
        else:
            print(end=" ")
    print()
# Out:
# ****
#  *  *
#  *  *
#  *  *
#  *  *
#  *  *
# ****

# %%
#15. Write a python program to print alphabet patten E.(Main Shape)

for row in range(0,7):
    for col in range(0,6):
        if((col==0) or (row==0 or row==3 or row==6) and (col>0)):
               print("*",end="")
        else:
               print(end="")
           
    print()
# Out:
# ******
# *
# *
# ******
# *
# *
# ******

# %%
#16. Write a python program to print alphabet pattern F.(Main Shape)

for row in range(0,7):
    for col in range(0,6):
        if((col==0) or (row==0 or row==3) and(col>0)):
            print("*",end="")
        else:
               print(end="")
           
    print()
# Out:
# ******
# *
# *
# ******
# *
# *
# *

# %%
#17.Write a python program to print alphabet pattern G.(Main Shape)

for row in range(0,7):
    for col in range(0,6):
        if col==0 or (col==4 and (row!=1 and row!=2)) or ((row==0 or row==6) and (col>0 and col<4)) or (row==3 and (col==3 or col==5)):
            print("*",end="")
        else:
               print(end=" ")
           
    print()
# Out:
# *****
# *
# *
# *  ***
# *   *
# *   *
# *****

# %%
#18.Write a python program to print alphabet pattern H.

for row in range(0,7):
    for col in range(0,6):
        if(col==0 or col==5) or (row==3) and (col>0 and col<5):
            print("*",end="")
        else:
            print(end=" ")
           
    print()
# Out:
# *    *
# *    *
# *    *
# ******
# *    *
# *    *
# *    *

# %%
#19. Write a python program to print alphabet pattern I.

for row in range(0,7):
    for col in range(0,6):
        if(col==3) or(row==0 or row==6) and (col>0 and col<6):
            print("*",end="")
        else:
               print(end=" ")
           
    print()
# Out:
#  *****
#    *
#    *
#    *
#    *
#    *
#  *****

# %%
#20.Write a python program to print alphabet pattern J.

for row in range(0,7):
    for col in range(0,5):
        if(col==2 or (row==0 and col!=2) or(row==6 and col<2) or (row==5 and col!=3 and col!=4 and col!=1)):
            print("*",end="")
        else:
            print(end=" ")
    print()
# Out:
# *****
#   *
#   *
#   *
#   *
# * *
# ***

# %%
#21.Write a python program to print alphabet pattern K.
i=0
j=4
for row in range(0,7):
    for col in range(0,5):
        if col==0 or (row==col+2 and col>1):
            print("*",end="")
        elif((row==i and col==j) and col>0):
            print("*",end="")
            i=i+1
            j=j-1
        else:
            print(end=" ")
    print()
# Out:
# *   *
# *  *
# * *
# **
# * *
# *  *
# *   *

# %%
#22.Write a python program to print alphabet pattern L.

for row in range(0,7):
    for col in range(0,7):
        if col==0 or (row==6 and col>0):
            print("*",end="")
        else:
            print(end=" ")
    print()
# Out:
# *
# *
# *
# *
# *
# *
# *******

# %%
#23.Write a python program to print alphabet patten M.

for row in range(0,7):
    for col in range(0,7):
        if col==0 or col==6 or ((row==col) and (col>0 and col<4)) or (row==1 and col==5) or(row==2 and col==4):
            print("*",end="")
        else:
            print(end=" ")
    print()
# Out:
# *     *
# **   **
# * * * *
# *  *  *
# *     *
# *     *
# *     *

# %%
#24.Write a python program to print alphabet pattern N.

for row in range(0,7):
    for col in range(0,8):
        if col==0 or col==7 or (row!=6) and (row==col and (col>0 and col<8)):
             print("*",end="")
        else:
            print(end=" ")
    print()
# Out:
# *      *
# **     *
# * *    *
# *  *   *
# *   *  *
# *    * *
# *      *

# %%
#25.Write a python program to print alphabet pattern O.

for row in range(0,6):
    for col in range(0,6):
        if((col==0 or col==4) and (row!=0 and row!=5)or (row==0 or row==5) and (col>0 and col<4)):
            print("*",end="")
        else:
            print(end=" ")
    print()
# Out:
#  ***
# *   *
# *   *
# *   *
# *   *
#  ***

# %%
#26.Write a python program to print alphabet pattern P.

for row in range(0,7):
    for col in range(0,5):
        if col==0 or (col==4 and (row==1 or row==2) or (row==0 or row==3) and (col>0 and col<4)):
                       print("*",end="")
        else:
            print(end=" ")
    print()
# Out:
# ****
# *   *
# *   *
# ****
# *
# *
# *

# %%
#27.Write a python program to print alphabet pattern Q.

for row in range(0,8):
    for col in range(0,5):
        if((col==0 or col==4) and (row>0 and row<6)) or ((row==0 or row==6) and (col>0 and col<4)) or (row==5 and col==1
                                                                                                      ) or (row==7 and col==3):
            print("*",end="")
        else:
            print(end=" ")
    print()
# Out:
#  ***
# *   *
# *   *
# *   *
# *   *
# **  *
#  ***
#    *

# %%
#28.Write a python program to print alphabet pattern R.

for row in range(0,7):
    for col in range(0,5):
        if col==0 or (col==4 and (row!=0 and row!=3)) or ((row==0 or row==3) and (col>0 and col<4)):
             print("*",end="")
        else:
             print(end=" ")
    print()
# Out:
# ****
# *   *
# *   *
# ****
# *   *
# *   *
# *   *

# %%
#29.Write a python program to print alphabet pattern S.

for row in range(0,7):
    for col in range(0,5):
        if ((row==0 or row==3 or row==6) and (col>0 and col<4)) or (col==0 and (row>0 and row<3)) or (col==4 and (row>3 and row<6)):
            print("*",end="")
        else:
            print(end=" ")
    print()
# Out:
#  ***
# *
# *
#  ***
#     *
#     *
#  ***

# %%
#30.Write a python program to print alphabet pattern print T.

for row in range(0,7):
    for col in range(0,8):
        if col==4 or (row==0 and col>0):
             print("*",end="")
        else:
            print(end=" ")
    print()
# Out:
#  *******
#     *
#     *
#     *
#     *
#     *
#     *

# %%
#31.Write a python program to print alphabet pattern U.

for row in range(0,7):
    for col in range(0,6):
        if (col==0 or col==5) and (row!=6) or (row==6 and (col>0 and col<5)):
             print("*",end="")
        else:
            print(end=" ")
    print()
# Out:
# *    *
# *    *
# *    *
# *    *
# *    *
# *    *
#  ****

# %%
#32.Write a python program to print alphabet pattern V.

for row in range
# Out:
#   File "<ipython-input-40-e74d849034dc>", line 3
#     for row in range
#                     ^
# SyntaxError: invalid syntax

# %%
#36.:-Write a python program to print odd numbers within a given range.

lower=int(input("enter the lower range"))
upper=int(input("enter the upper range"))
for i in range(lower,upper+1):
    if(i%2!=0):
        print("odd series",i)
# Out:
# enter the lower range5
# enter the upper range10
# odd series 5
# odd series 7
# odd series 9

# %%
#37.:-Write a python program to check the name and password by the user.
name=input("enter name:")
password=input("enter password")
if name==('prateek'):
    print('hello prateek')
else:
    print('name error')
if password==('saxena'):
    print('access granted')
else:
    print('wrong password')

# %%
#38.1Swap two numbers:-First Method
a=2
b=5
a,b=b,a
print(a,b)

# %%
#38.2Second Method:-Swap two numbers within the temp variable.
a=6
b=2
c=a
a=b
b=c
print(a,b)

# %%
#38.3third Method:-Swap two numbers without temp variable.
a=8
b=2
a=a+b
b=a-b
a=a-b
print(a,b)

# %%
#39.
i=int(input("enter a number"))
for i in range(0,21):
    if(i%4==0):
        print("fizz")
    elif(i%5==0):
        print("buzz")
    else:
        print("fizzbuzz")
# Out:
# enter a number16
# fizz
# fizzbuzz
# fizzbuzz
# fizzbuzz
# fizz
# buzz
# fizzbuzz
# fizzbuzz
# fizz
# fizzbuzz
# buzz
# fizzbuzz
# fizz
# fizzbuzz
# fizzbuzz
# buzz
# fizz
# fizzbuzz
# fizzbuzz
# fizzbuzz
# fizz

# %%
#40.
n=input("enter a name")
t=('thequickbrownfoxjumpsoverthelazydog')
for i in range(len(t)):
    if i not in n:
        print("not pangram")
    else:
        print("pangram")
# Out:
# enter a nameprateek
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-de2b2536de31> in <module>
#       3 t=('thequickbrownfoxjumpsoverthelazydog')
#       4 for i in range(len(t)):
# ----> 5     if i not in n:
#       6         print("not pangram")
#       7     else:
#
# TypeError: 'in <string>' requires string as left operand, not int

# %%
x=int(input("enter x number"))
y=int(input("enter y number"))
z=x+y
if z>=15 and z<=20:
    print("sum is",20)
else:
    print("sum is",z)
# Out:
# enter x number10
# enter y number6
# sum is 20
